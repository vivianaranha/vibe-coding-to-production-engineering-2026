# %% [markdown]
# # AI Boundary\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom vibeprod.ai import MockAI,valid_structured\nr=MockAI().generate("ticket");print(r,valid_structured(r,["text","provider"]))
