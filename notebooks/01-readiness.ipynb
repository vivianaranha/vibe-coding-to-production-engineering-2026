# %% [markdown]
# # Readiness\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom vibeprod.readiness import score,missing\nc={"requirements":1,"tests":1,"security":0};print(score(c),missing(c))
