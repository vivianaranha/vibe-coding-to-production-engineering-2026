# %% [markdown]
# # Quality Gate\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom vibeprod.quality import release_gate\nprint(release_gate(True,True,True,False))
