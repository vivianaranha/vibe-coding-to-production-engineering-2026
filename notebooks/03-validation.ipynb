# %% [markdown]
# # Validation\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom vibeprod.validation import require_text\nprint(require_text(" hello "))
