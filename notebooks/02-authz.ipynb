# %% [markdown]
# # Authorization\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom vibeprod.authz import can,same_tenant\nprint(can("editor","update"),same_tenant("a","b","editor"))
